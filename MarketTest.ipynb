# %%
from MarketSimulator import MarketSimulator
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
simulator = MarketSimulator("data.csv")
# trading_state = simulator.build_trading_state(timestamp=100)
# simulator.df.head()
log = simulator.simulate()
# Out:
# --- Timestamp 0 ---
# SELL 1x 2028
# SELL KELP:  price=2028, quantity=1 | realized P&L=2028.00
#
# --- Timestamp 100 ---
# SELL 24x 2025
# SELL KELP:  price=2025, quantity=24 | realized P&L=48600.00
#
# --- Timestamp 200 ---
# SELL 22x 2025
# SELL KELP:  price=2025, quantity=22 | realized P&L=44550.00
#
# --- Timestamp 300 ---
# SELL 31x 2025
#
# --- Timestamp 400 ---
# SELL 27x 2025
#
# --- Timestamp 500 ---
# SELL 30x 2025
#
# --- Timestamp 600 ---
# SELL 5x 2026
#
# --- Timestamp 700 ---
# SELL 2x 2025
# SELL KELP:  price=2025, quantity=2 | realized P&L=4050.00
#
# --- Timestamp 800 ---
# SELL 1x 2024
# SELL KELP:  price=2024, quantity=1 | realized P&L=2024.00
#
# --- Timestamp 900 ---
# SELL 23x 2024
#
# --- Timestamp 1000 ---
# SELL 26x 2024
#
# --- Timestamp 1100 ---
# SELL 6x 2025
#
# --- Timestamp 1200 ---
# SELL 21x 2024
#
# --- Timestamp 1300 ---
# SELL 31x 2024
#
# --- Timestamp 1400 ---
# SELL 3x 2025
#
# --- Timestamp 1500 ---
# SELL 27x 2024
#
# --- Timestamp 1600 ---
# ...

# %%
log
# Out:
#    timestamp symbol  price  quantity  position  profit_loss  \
# 0          0   KELP   2028        -1        -1         2028
# 1        100   KELP   2025       -24       -25        50628
# 2        200   KELP   2025       -22       -47        95178
# 3        700   KELP   2025        -2       -49        99228
# 4        800   KELP   2024        -1       -50       101252
#
#    realized_profit_loss
# 0                2028.0
# 1               50628.0
# 2               95178.0
# 3               99228.0
# 4              101252.0
